# %%
import fiftyone as fo
# Out:
# ---------------------------------------------------------------------------
# ServiceExecutableNotFound                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/py9/lib/python3.9/site-packages/fiftyone/core/odm/database.py:103, in establish_db_conn(config)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/py9/lib/python3.9/site-packages/fiftyone/core/odm/database.py?line=101'>102</a> try:
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/py9/lib/python3.9/site-packages/fiftyone/core/odm/database.py?line=102'>103</a>     _db_service = fos.DatabaseService()
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/py9/lib/python3.9/site-packages/fiftyone/core/odm/database.py?line=103'>104</a>     port = _db_service.port
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/py9/lib/python3.9/site-packages/fiftyone/core/service.py:80, in Service.__init__(self)
# ...

# %%
# Create a dataset from a glob pattern of images
dataset = fo.Dataset.from_images_patt("train/*/*.jpg")

session = fo.launch_app(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/snape/Documents/vinted/test_51.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/snape/Documents/vinted/test_51.ipynb#ch0000001?line=0'>1</a> # Create a dataset from a glob pattern of images
# ----> <a href='vscode-notebook-cell:/Users/snape/Documents/vinted/test_51.ipynb#ch0000001?line=1'>2</a> dataset = fo.Dataset.from_images_patt("train/*/*.jpg")
#       <a href='vscode-notebook-cell:/Users/snape/Documents/vinted/test_51.ipynb#ch0000001?line=3'>4</a> session = fo.launch_app(dataset)
#
# NameError: name 'fo' is not defined
